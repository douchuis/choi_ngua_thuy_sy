# %%
import requests
from bs4 import BeautifulSoup
import time

# %%
links = []
for i in range(26):
    
    url = 'http://example.webscraping.com/places/default/index/' + str(i)
    response = requests.get(url)
    print(response)
    if response.ok:
        print('Page: ' + str(i))
        soup = BeautifulSoup(response.text,'lxml')
        tds =soup.findAll('td')
        for td in tds:
            a = td.find('a')
            print(a)
#             link = a['href']
#             links.append('http://example.webscraping.com' + link)
    time.sleep(1)
"""
for x in range(26):
    print(links[x])
"""            
# print(len(links))
# Out:
# <Response [200]>
# Page: 0
# <a href="/places/default/view/Afghanistan-1"><img src="/places/static/images/flags/af.png"/> Afghanistan</a>
# <a href="/places/default/view/Aland-Islands-2"><img src="/places/static/images/flags/ax.png"/> Aland Islands</a>
# <a href="/places/default/view/Albania-3"><img src="/places/static/images/flags/al.png"/> Albania</a>
# <a href="/places/default/view/Algeria-4"><img src="/places/static/images/flags/dz.png"/> Algeria</a>
# <a href="/places/default/view/American-Samoa-5"><img src="/places/static/images/flags/as.png"/> American Samoa</a>
# <a href="/places/default/view/Andorra-6"><img src="/places/static/images/flags/ad.png"/> Andorra</a>
# <a href="/places/default/view/Angola-7"><img src="/places/static/images/flags/ao.png"/> Angola</a>
# <a href="/places/default/view/Anguilla-8"><img src="/places/static/images/flags/ai.png"/> Anguilla</a>
# <a href="/places/default/view/Antarctica-9"><img src="/places/static/images/flags/aq.png"/> Antarctica</a>
# <a href="/places/default/view/Antigua-and-Barbuda-10"><img src="/places/static/images/flags/ag.png"/> Antigua and Barbuda</a>
# <Response [200]>
# Page: 1
# <a href="/places/default/view/Argentina-11"><img src="/places/static/images/flags/ar.png"/> Argentina</a>
# <a href="/places/default/view/Armenia-12"><img src="/places/static/images/flags/am.png"/> Armenia</a>
# <a href="/places/default/view/Aruba-13"><img src="/places/static/images/flags/aw.png"/> Aruba</a>
# <a href="/places/default/view/Australia-14"><img src="/places/static/images/flags/au.png"/> Australia</a>
# <a href="/places/default/view/Austria-15"><img src="/places/static/images/flags/at.png"/> Austria</a>
# <a href="/places/default/view/Azerbaijan-16"><img src="/places/static/images/flags/az.png"/> Azerbaijan</a>
# <a href="/places/default/view/Bahamas-17"><img src="/places/static/images/flags/bs.png"/> Bahamas</a>
# <a href="/places/default/view/Bahrain-18"><img src="/places/static/images/flags/bh.png"/> Bahrain</a>
# <a href="/places/default/view/Bangladesh-19"><img src="/places/static/images/flags/bd.png"/> Bangladesh</a>
# <a href="/places/default/view/Barbados-20"><img src="/places/static/images/flags/bb.png"/> Barbados</a>
# <Response [200]>
# Page: 2
# <a href="/places/default/view/Belarus-21"><img src="/places/static/images/flags/by.png"/> Belarus</a>
# <a href="/places/default/view/Belgium-22"><img src="/places/static/images/flags/be.png"/> Belgium</a>
# <a href="/places/default/view/Belize-23"><img src="/places/static/images/flags/bz.png"/> Belize</a>
# <a href="/places/default/view/Benin-24"><img src="/places/static/images/flags/bj.png"/> Benin</a>
# <a href="/places/default/view/Bermuda-25"><img src="/places/static/images/flags/bm.png"/> Bermuda</a>
# <a href="/places/default/view/Bhutan-26"><img src="/places/static/images/flags/bt.png"/> Bhutan</a>
# <a href="/places/default/view/Kenya-116"><img src="/places/static/images/flags/ke.png"/> Kenya</a>
# <a href="/places/default/view/Kiribati-117"><img src="/places/static/images/flags/ki.png"/> Kiribati</a>
# <a href="/places/default/view/Kosovo-118"><img src="/places/static/images/flags/xk.png"/> Kosovo</a>
# <a href="/places/default/view/Kuwait-119"><img src="/places/static/images/flags/kw.png"/> Kuwait</a>
# <a href="/places/default/view/Kyrgyzstan-120"><img src="/places/static/images/flags/kg.png"/> Kyrgyzstan</a>
# <Response [200]>
# Page: 12
# <a href="/places/default/view/Laos-121"><img src="/places/static/images/flags/la.png"/> Laos</a>
# <a href="/places/default/view/Latvia-122"><img src="/places/static/images/flags/lv.png"/> Latvia</a>
# <a href="/places/default/view/Lebanon-123"><img src="/places/static/images/flags/lb.png"/> Lebanon</a>
# <a href="/places/default/view/Lesotho-124"><img src="/places/static/images/flags/ls.png"/> Lesotho</a>
# <a href="/places/default/view/Liberia-125"><img src="/places/static/images/flags/lr.png"/> Liberia</a>
# <a href="/places/default/view/Libya-126"><img src="/places/static/images/flags/ly.png"/> Libya</a>
# <a href="/places/default/view/Liechtenstein-127"><img src="/places/static/images/flags/li.png"/> Liechtenstein</a>
# <a href="/places/default/view/Lithuania-128"><img src="/places/static/images/flags/lt.png"/> Lithuania</a>
# <a href="/places/default/view/Luxembourg-129"><img src="/places/static/images/flags/lu.png"/> Luxembourg</a>
# <a href="/places/default/view/Macao-130"><img src="/places/static/images/flags/mo.png"/> Macao</a>
# <Response [200]>
# Page: 13
# <a href="/places/default/view/Macedonia-131"><img src="/places/static/images/flags/mk.png"/> Macedonia</a>
# <a href="/places/default/view/Madagascar-132"><img src="/places/static/images/flags/mg.png"/> Madagascar</a>
# <a href="/places/default/view/Malawi-133"><img src="/places/static/images/flags/mw.png"/> Malawi</a>
# <a href="/places/default/view/Malaysia-134"><img src="/places/static/images/flags/my.png"/> Malaysia</a>
# <a href="/places/default/view/Maldives-135"><img src="/places/static/images/flags/mv.png"/> Maldives</a>
# <a href="/places/default/view/Mali-136"><img src="/places/static/images/flags/ml.png"/> Mali</a>
# <a href="/places/default/view/Malta-137"><img src="/places/static/images/flags/mt.png"/> Malta</a>
# <a href="/places/default/view/Marshall-Islands-138"><img src="/places/static/images/flags/mh.png"/> Marshall Islands</a>
# <a href="/places/default/view/Martinique-139"><img src="/places/static/images/flags/mq.png"/> Martinique</a>
# <a href="/places/default/view/Mauritania-140"><img src="/places/static/images/flags/mr.png"/> Mauritania</a>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-747587b031f5> in <module>
#      14 #             link = a['href']
#      15 #             links.append('http://example.webscraping.com' + link)
# ---> 16     time.sleep(1)
#      17 """
#      18 for x in range(26):
#
# KeyboardInterrupt:

# %%
with open('urls.txt','w') as file:
    for link in links:
        file.write(link + '\n')

# %%
with open('urls.txt','r') as inf:
    with open('pays.csv','w') as outf:
        outf.write('pays,population\n')
        for row in inf:
            url = row.strip()
            response = requests.get(url)
            if response.ok:
                soup = BeautifulSoup(response.text,'lxml')
                country = soup.find('tr',{'id':'places_country__row'}).find('td',{'class':'w2p_fw'})
                pop = soup.find('tr',{'id':'places_population__row'}).find('td',{'class':'w2p_fw'})
                print('Pays: ' + country.text + 'Pop: ' + pop.text)
                outf.write(country.text + ',' + pop.text.replace(',','') + '\n')
                
            time.sleep(3)
# Out:
# Pays: AfghanistanPop: 29,121,286
# Pays: Aland IslandsPop: 26,711
# Pays: AlbaniaPop: 2,986,952
# Pays: AlgeriaPop: 34,586,184
# Pays: American SamoaPop: 57,881
# Pays: AndorraPop: 84,000
# Pays: AngolaPop: 13,068,161
# Pays: AnguillaPop: 13,254
# Pays: AntarcticaPop: 0
# Pays: Antigua and BarbudaPop: 86,754
# Pays: ArgentinaPop: 41,343,201
# Pays: ArmeniaPop: 2,968,000
# Pays: ArubaPop: 71,566
# Pays: AustraliaPop: 21,515,754
# Pays: AustriaPop: 8,205,000
# Pays: AzerbaijanPop: 8,303,512
# Pays: BahamasPop: 301,790
# Pays: BahrainPop: 738,004
# Pays: BangladeshPop: 156,118,464
# Pays: BarbadosPop: 285,653
# Pays: BelarusPop: 9,685,000
# Pays: BelgiumPop: 10,403,000
# Pays: BelizePop: 314,522
# Pays: BeninPop: 9,056,010
# Pays: BermudaPop: 65,365
# Pays: BhutanPop: 699,847
# Pays: BoliviaPop: 9,947,418
# Pays: Bonaire, Saint Eustatius and SabaPop: 18,012
# Pays: Bosnia and HerzegovinaPop: 4,590,000
# Pays: BotswanaPop: 2,029,307
# Pays: Bouvet IslandPop: 0
# Pays: BrazilPop: 201,103,330
# Pays: British Indian Ocean TerritoryPop: 4,000
# Pays: British Virgin IslandsPop: 21,730
# Pays: BruneiPop: 395,027
# Pays: BulgariaPop: 7,148,785
# Pays: Burkina FasoPop: 16,241,811
# Pays: BurundiPop: 9,863,117
# Pays: CambodiaPop: 14,453,680
# Pays: CameroonPop: 19,294,149
# Pays: CanadaPop: 33,679,000
# Pays: Cape VerdePop: 508,659
# Pays: Cayman IslandsPop: 44,270
# Pays: Central African RepublicPop: 4,844,927
# Pays: ChadPop: 10,543,464
# Pays: ChilePop: 16,746,491
# Pays: ChinaPop: 1,330,044,000
# Pays: Christmas IslandPop: 1,500
# Pays: Cocos IslandsPop: 628
# Pays: ColombiaPop: 44,205,293
# Pays: ComorosPop: 773,407
# Pays: Cook IslandsPop: 21,388
# Pays: Costa RicaPop: 4,516,220
# Pays: CroatiaPop: 4,491,000
# Pays: CubaPop: 11,423,000
# Pays: CuracaoPop: 141,766
# Pays: CyprusPop: 1,102,677
# Pays: Czech RepublicPop: 10,476,000
# Pays: Democratic Republic of the CongoPop: 70,916,439
# Pays: DenmarkPop: 5,484,000
# Pays: DjiboutiPop: 740,528
# Pays: DominicaPop: 72,813
# Pays: Dominican RepublicPop: 9,823,821
# Pays: East TimorPop: 1,154,625
# Pays: EcuadorPop: 14,790,608
# Pays: EgyptPop: 80,471,869
# Pays: El SalvadorPop: 6,052,064
# Pays: Equatorial GuineaPop: 1,014,999
# Pays: EritreaPop: 5,792,984
# Pays: EstoniaPop: 1,291,170
# Pays: EthiopiaPop: 88,013,491
# Pays: Falkland IslandsPop: 2,638
# Pays: Faroe IslandsPop: 48,228
# Pays: FijiPop: 875,983
# Pays: FinlandPop: 5,244,000
# Pays: FrancePop: 64,768,389
# Pays: French GuianaPop: 195,506
# Pays: French PolynesiaPop: 270,485
# Pays: French Southern TerritoriesPop: 140
# Pays: GabonPop: 1,545,255
# Pays: GambiaPop: 1,593,256
# Pays: GeorgiaPop: 4,630,000
# Pays: GermanyPop: 81,802,257
# Pays: GhanaPop: 24,339,838
# Pays: GibraltarPop: 27,884
# Pays: GreecePop: 11,000,000
# Pays: GreenlandPop: 56,375
# Pays: GrenadaPop: 107,818
# Pays: GuadeloupePop: 443,000
# Pays: GuamPop: 159,358
# Pays: GuatemalaPop: 13,550,440
# Pays: GuernseyPop: 65,228
# Pays: GuineaPop: 10,324,025
# Pays: Guinea-BissauPop: 1,565,126
# Pays: GuyanaPop: 748,486
# Pays: HaitiPop: 9,648,924
# Pays: Heard Island and McDonald IslandsPop: 0
# Pays: HondurasPop: 7,989,415
# Pays: Hong KongPop: 6,898,686
# Pays: HungaryPop: 9,982,000
# Pays: IcelandPop: 308,910
# Pays: IndiaPop: 1,173,108,018
# Pays: IndonesiaPop: 242,968,342
# Pays: IranPop: 76,923,300
# Pays: IraqPop: 29,671,605
# Pays: IrelandPop: 4,622,917
# Pays: Isle of ManPop: 75,049
# Pays: IsraelPop: 7,353,985
# Pays: ItalyPop: 60,340,328
# Pays: Ivory CoastPop: 21,058,798
# Pays: JamaicaPop: 2,847,232
# Pays: JapanPop: 127,288,000
# Pays: JerseyPop: 90,812
# Pays: JordanPop: 6,407,085
# Pays: KazakhstanPop: 15,340,000
# Pays: KenyaPop: 40,046,566
# Pays: KiribatiPop: 92,533
# Pays: KosovoPop: 1,800,000
# Pays: KuwaitPop: 2,789,132
# Pays: KyrgyzstanPop: 5,508,626
# Pays: LaosPop: 6,368,162
# Pays: LatviaPop: 2,217,969
# Pays: LebanonPop: 4,125,247
# Pays: LesothoPop: 1,919,552
# Pays: LiberiaPop: 3,685,076
# Pays: LibyaPop: 6,461,454
# Pays: LiechtensteinPop: 35,000
# Pays: LithuaniaPop: 3,565,000
# Pays: LuxembourgPop: 497,538
# Pays: MacaoPop: 449,198
# Pays: MacedoniaPop: 2,062,294
# Pays: MadagascarPop: 21,281,844
# Pays: MalawiPop: 15,447,500
# Pays: MalaysiaPop: 28,274,729
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-274207cbf831> in <module>
#       4         for row in inf:
#       5             url = row.strip()
# ----> 6             response = requests.get(url)
#       7             if response.ok:
#       8                 soup = BeautifulSoup(response.text,'lxml')
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# C:\ProgramData\Anaconda3\lib\http\client.py in getresponse(self)
#    1334         try:
#    1335             try:
# -> 1336                 response.begin()
#    1337             except ConnectionError:
#    1338                 self.close()
#
# C:\ProgramData\Anaconda3\lib\http\client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# C:\ProgramData\Anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
import pandas as pd 
import numpy as np

# %%
pays = pd.read_csv('pays.csv')
pays.head()
# Out:
#              pays  population
# 0     Afghanistan    29121286
# 1   Aland Islands       26711
# 2         Albania     2986952
# 3         Algeria    34586184
# 4  American Samoa       57881
